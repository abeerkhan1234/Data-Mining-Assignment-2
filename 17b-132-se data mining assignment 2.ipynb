# %%
import numpy as np
import pandas as pd
# import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# For predictive data analysis
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_curve

# %%
train = pd.read_csv(r"C:\Users\pc\Downloads\train.csv")

# %%
test = pd.read_csv(r"C:\Users\pc\Downloads\train.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.shape
# Out:
# (891, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.describe().T.style.set_properties(**{'background-color': 'grey','color': 'white','border-color': 'white'})
# Out:
# <style type="text/css">
# #T_f88f3_row0_col0, #T_f88f3_row0_col1, #T_f88f3_row0_col2, #T_f88f3_row0_col3, #T_f88f3_row0_col4, #T_f88f3_row0_col5, #T_f88f3_row0_col6, #T_f88f3_row0_col7, #T_f88f3_row1_col0, #T_f88f3_row1_col1, #T_f88f3_row1_col2, #T_f88f3_row1_col3, #T_f88f3_row1_col4, #T_f88f3_row1_col5, #T_f88f3_row1_col6, #T_f88f3_row1_col7, #T_f88f3_row2_col0, #T_f88f3_row2_col1, #T_f88f3_row2_col2, #T_f88f3_row2_col3, #T_f88f3_row2_col4, #T_f88f3_row2_col5, #T_f88f3_row2_col6, #T_f88f3_row2_col7, #T_f88f3_row3_col0, #T_f88f3_row3_col1, #T_f88f3_row3_col2, #T_f88f3_row3_col3, #T_f88f3_row3_col4, #T_f88f3_row3_col5, #T_f88f3_row3_col6, #T_f88f3_row3_col7, #T_f88f3_row4_col0, #T_f88f3_row4_col1, #T_f88f3_row4_col2, #T_f88f3_row4_col3, #T_f88f3_row4_col4, #T_f88f3_row4_col5, #T_f88f3_row4_col6, #T_f88f3_row4_col7, #T_f88f3_row5_col0, #T_f88f3_row5_col1, #T_f88f3_row5_col2, #T_f88f3_row5_col3, #T_f88f3_row5_col4, #T_f88f3_row5_col5, #T_f88f3_row5_col6, #T_f88f3_row5_col7, #T_f88f3_row6_col0, #T_f88f3_row6_col1, #T_f88f3_row6_col2, #T_f88f3_row6_col3, #T_f88f3_row6_col4, #T_f88f3_row6_col5, #T_f88f3_row6_col6, #T_f88f3_row6_col7 {
#   background-color: grey;
#   color: white;
#   border-color: white;
# }
# </style>
# <table id="T_f88f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f88f3_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_f88f3_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_f88f3_row0_col1" class="data row0 col1" >446.000000</td>
#       <td id="T_f88f3_row0_col2" class="data row0 col2" >257.353842</td>
#       <td id="T_f88f3_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f88f3_row0_col4" class="data row0 col4" >223.500000</td>
#       <td id="T_f88f3_row0_col5" class="data row0 col5" >446.000000</td>
#       <td id="T_f88f3_row0_col6" class="data row0 col6" >668.500000</td>
#       <td id="T_f88f3_row0_col7" class="data row0 col7" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_
row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_f88f3_row6_col4" class="data row6 col4" >7.910400</td>
#       <td id="T_f88f3_row6_col5" class="data row6 col5" >14.454200</td>
#       <td id="T_f88f3_row6_col6" class="data row6 col6" >31.000000</td>
#       <td id="T_f88f3_row6_col7" class="data row6 col7" >512.329200</td>
#     </tr>
#   </tbody>
# </table>

# %%
def missing (train):
    missing_number = train.isnull().sum().sort_values(ascending=False)
    missing_percent = ((train.isnull().sum()/train.isnull().count())*100).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

# %%
missing (train)
# Out:
#              Missing_Number  Missing_Percent
# Cabin                   687        77.104377
# Age                     177        19.865320
# Embarked                  2         0.224467
# PassengerId               0         0.000000
# Survived                  0         0.000000
# Pclass                    0         0.000000
# Name                      0         0.000000
# Sex                       0         0.000000
# SibSp                     0         0.000000
# Parch                     0         0.000000
# Ticket                    0         0.000000
# Fare                      0         0.000000

# %%
missing (train)
# Out:
#              Missing_Number  Missing_Percent
# Cabin                   687        77.104377
# Age                     177        19.865320
# Embarked                  2         0.224467
# PassengerId               0         0.000000
# Survived                  0         0.000000
# Pclass                    0         0.000000
# Name                      0         0.000000
# Sex                       0         0.000000
# SibSp                     0         0.000000
# Parch                     0         0.000000
# Ticket                    0         0.000000
# Fare                      0         0.000000

# %%
for i in train.columns:
    if train[i].dtypes == 'object':
        train[i].fillna(train[i].mode()[0], inplace=True)
    else:
        train[i].fillna(train[i].median(), inplace=True)
print(train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked
# 0        0         A/5 21171   7.2500  B96 B98        S
# 1        0          PC 17599  71.2833      C85        C
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S
# 3        0            113803  53.1000     C123        S
# 4        0            373450   8.0500  B96 B98        S
# ..     ...               ...      ...      ...      ...
# 886      0            211536  13.0000  B96 B98        S
# 887      0            112053  30.0000      B42        S
# 888      2        W./C. 6607  23.4500  B96 B98        S
# 889      0            111369  30.0000     C148        C
# 890      0            370376   7.7500  B96 B98        Q
#
# [891 rows x 12 columns]

# %%
sns.countplot(train.dtypes.map(str))
plt.show()
# Out:
# F:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for i in test.columns:
    if test[i].dtypes == 'object':
        test[i].fillna(test[i].mode()[0], inplace=True)
    else:
        test[i].fillna(test[i].median(), inplace=True)
print(test)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked
# 0        0         A/5 21171   7.2500  B96 B98        S
# 1        0          PC 17599  71.2833      C85        C
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S
# 3        0            113803  53.1000     C123        S
# 4        0            373450   8.0500  B96 B98        S
# ..     ...               ...      ...      ...      ...
# 886      0            211536  13.0000  B96 B98        S
# 887      0            112053  30.0000      B42        S
# 888      2        W./C. 6607  23.4500  B96 B98        S
# 889      0            111369  30.0000     C148        C
# 890      0            370376   7.7500  B96 B98        Q
#
# [891 rows x 12 columns]

# %%
sns.countplot(test.dtypes.map(str))
plt.show()
# Out:
# F:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
plt.figure(figsize = (20,10))
sns.histplot(x = "Age", data = train)
plt.title("Histogram (Age)")
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.kdeplot(x = "Age", data = train, fill = True)
plt.title("KDE (Age)")
plt.show()

# %%
plt.figure(figsize = (20,2))
sns.boxplot(x = "Age", data = train)
plt.title("Boxplot (Age)")
plt.show()

# %%
plt.figure(figsize = (20,2))
sns.violinplot(x = "Age", data = train)
plt.title("Violin plot (Age)")
plt.show()

# %%
plt.figure(figsize = (20,2))
sns.violinplot(x = "Age", data = train)
plt.title("Violin plot (Age)")
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.histplot(x = "Fare", data = train)
plt.title("Histogram (Fare)")
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.countplot(x = "Sex", data = train)
plt.title("Countplot (Sex)")
plt.xticks([0, 1], ["Male", "Female"])
plt.show()

# %%
plt.figure(figsize = (20, 10))
sns.countplot(x = "Pclass", hue = "Survived", data = train)
plt.title("Survived VS Pclass")
plt.show()

# %%
plt.figure(figsize = (20, 10))
sns.kdeplot(x = "Age", hue = "Survived", data = train, shade = True)
plt.title("Survived VS Age")
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize = (20, 20))

sns.violinplot(x = "Pclass", y = "Age", hue = "Survived", split = True, data = train, ax = axes[0, 0])
sns.violinplot(x = "Sex", y = "Age", hue = "Survived", split = True, data = train, ax = axes[0, 1])
sns.violinplot(x = "SibSp", y = "Age", hue = "Survived", split = True, data = train, ax = axes[1, 0])
sns.violinplot(x = "Parch", y = "Age", hue = "Survived", split = True, data = train, ax = axes[1, 1])
sns.violinplot(x = "Embarked", y = "Age", hue = "Survived", split = True, data = train, ax = axes[2, 0])
sns.violinplot(x = "Cabin", y = "Age", hue = "Survived", split = True, data = train, ax = axes[2, 1])
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Age'>

# %%
plt.figure(figsize = (10, 5))
sns.barplot(train['Pclass'],train['Age'],hue=train['Sex'])
plt.show()
# Out:
# F:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (10, 5))
sns.heatmap(pd.crosstab(train['Pclass'],train['Survived']))
plt.show()
